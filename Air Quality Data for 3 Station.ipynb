# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("air_quality_no2.csv")
data
# Out:
#              datetime  station_antwerp  station_paris  station_london
# 0       5/7/2019 2:00              NaN            NaN            23.0
# 1       5/7/2019 3:00             50.5           25.0            19.0
# 2       5/7/2019 4:00             45.0           27.7            19.0
# 3       5/7/2019 5:00              NaN           50.4            16.0
# 4       5/7/2019 6:00              NaN           61.9             NaN
# ...               ...              ...            ...             ...
# 1030  6/20/2019 22:00              NaN           21.4             NaN
# 1031  6/20/2019 23:00              NaN           24.9             NaN
# 1032   6/21/2019 0:00              NaN           26.5             NaN
# 1033   6/21/2019 1:00              NaN           21.8             NaN
# 1034   6/21/2019 2:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
data['datetime']
# Out:
# 0         5/7/2019 2:00
# 1         5/7/2019 3:00
# 2         5/7/2019 4:00
# 3         5/7/2019 5:00
# 4         5/7/2019 6:00
#              ...
# 1030    6/20/2019 22:00
# 1031    6/20/2019 23:00
# 1032     6/21/2019 0:00
# 1033     6/21/2019 1:00
# 1034     6/21/2019 2:00
# Name: datetime, Length: 1035, dtype: object

# %%
plt.plot(data.station_antwerp)
plt.title("Station Wise Timetable")
# Out:
# Text(0.5, 1.0, 'Station Wise Timetable')

# %%
plt.plot(data.station_antwerp)
plt.title("Antwerp Timetable")
# Out:
# Text(0.5, 1.0, 'Antwerp Timetable')

# %%
plt.plot(data.station_paris)
plt.title("Paris Timetable")
# Out:
# Text(0.5, 1.0, 'Paris Timetable')

# %%
plt.plot(data.station_london)
plt.title("London Timetable")
# Out:
# Text(0.5, 1.0, 'London Timetable')

# %%
x=data['station_paris']
y=data['station_london']

plt.scatter(x,y)

# %%
data['station_antwerp'].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
data['station_paris'].plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
data['station_london'].plot.box(vert=False)
# Out:
# <AxesSubplot:>
