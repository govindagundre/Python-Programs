# %%
import pandas as pd

#Load Dataset 
dt1 = pd.read_excel('Bank_customer_churn_modelling.xlsx')

dt1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dt2=data=pd.read_csv('iris_flowers.csv')
dt2
# Out:
#      sepal_length  sepal_width  petal_length   petal_width           class
# 0             5.1          3.5           1.4           0.2     iris_setosa
# 1             4.9          3.0           1.4           0.2     iris_setosa
# 2             4.7          3.2           1.3           0.2     iris_setosa
# 3             4.6          3.1           1.5           0.2     iris_setosa
# 4             5.0          3.6           1.4           0.2     iris_setosa
# ..            ...          ...           ...           ...             ...
# 145           6.7          3.0           5.2           2.3  iris_virginica
# 146           6.3          2.5           5.0           1.9  iris_virginica
# 147           6.5          3.0           5.2           2.0  iris_virginica
# 148           6.2          3.4           5.4           2.3  iris_virginica
# 149           5.9          3.0           5.1           1.8  iris_virginica
#
# [150 rows x 5 columns]

# %%
data=pd.concat([dt1,dt2])

# %%
data
# Out:
#      RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1.0  15634602.0  Hargrave        619.0    France  Female  42.0
# 1          2.0  15647311.0      Hill        608.0     Spain  Female  41.0
# 2          3.0  15619304.0      Onio        502.0    France  Female  42.0
# 3          4.0  15701354.0      Boni        699.0    France  Female  39.0
# 4          5.0  15737888.0  Mitchell        850.0     Spain  Female  43.0
# ..         ...         ...       ...          ...       ...     ...   ...
# 145        NaN         NaN       NaN          NaN       NaN     NaN   NaN
# 146        NaN         NaN       NaN          NaN       NaN     NaN   NaN
# 147        NaN         NaN       NaN          NaN       NaN     NaN   NaN
# 148        NaN         NaN       NaN          NaN       NaN     NaN   NaN
# 149        NaN         NaN       NaN          NaN       NaN     NaN   NaN
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.merge(data,dt1,how="left",on="CustomerId")

#df.merge(df, df1, how="left" , on="common_coloumnname")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d44ef912488f> in <module>
# ----> 1 data.merge(data,dt1,how="left",on="CustomerId")
#       2
#       3 #df.merge(df, df1, how="left" , on="common_coloumnname")
#
# TypeError: merge() got multiple values for argument 'how'
